# %% [markdown]
# # New Clue
# In this notebook, we'll test the new, simplified CLUE implementation. We're not using Bayesian Neural Networks here, so the uncertainty is just the entropy of the classifier.

# %% [markdown]
# ## Setup

# %% [markdown]
# Import libraries

# %%
import importlib
import models.regene_models as regene_models
importlib.reload(regene_models)
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import os
import clue.new_CLUE as new_CLUE
importlib.reload(new_CLUE)
import models.BLL
import models.mnist_classifier_BLL
import models.BLL_VI
import models.regene_models

# %% [markdown]
# Set the configuration

# %%
# 1. Configuration
class Config:
    # Data
    train = False    # Evaluate on validation set every epoch
    latent_dim = 256
    
    # Hardware
    device = 'cuda' if torch.cuda.is_available() \
    else 'mps' if torch.backends.mps.is_available() \
    else 'cpu'
    
cfg = Config()

# %% [markdown]
# Load the Datasets

# %%
# Load the MNIST dataset
transform = transforms.Compose([transforms.ToTensor()])
trainset = torchvision.datasets.MNIST(root='../data', train=True, download=True, transform=transform)
testset = torchvision.datasets.MNIST(root='../data', train=False, download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False, num_workers=2)

# %% [markdown]
# Create a models directory if it doesn't exist

# %%
# Create models directory if it doesn't exist
os.makedirs('../model_saves', exist_ok=True)
model_saves_dir = '../model_saves'

# %% [markdown]
# ## Prepare the Backbone and Decoder
# We'll be testing the CLUE implementation on the BLL model. We first need load (or train) the decoder.

# %% [markdown]
# ### Load the models

# %% [markdown]
# We load the backbone classifier

# %%
backbone = regene_models.Classifier(latent_dim=cfg.latent_dim, num_classes=10, device=cfg.device)
print(f"Backbone will run on: {cfg.device}")
# Out:
# Backbone will run on: mps

# %% [markdown]
# Load weights

# %%
backbone.load_state_dict(torch.load(os.path.join(model_saves_dir, 'joint_classifier.pth'), map_location=cfg.device))
# Out:
# /var/folders/tb/ccwl9r592hn9v_xpq9s1bzlr0000gn/T/ipykernel_21837/613504044.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   backbone.load_state_dict(torch.load(os.path.join(model_saves_dir, 'joint_classifier.pth'), map_location=cfg.device))
# <All keys matched successfully>

# %% [markdown]
# Next, define the decoder

# %%
decoder = regene_models.Decoder(latent_dim=256, device=cfg.device)

# %% [markdown]
# And load it

# %%
decoder.load_state_dict(torch.load(os.path.join(model_saves_dir, 'joint_decoder.pth'), map_location=cfg.device))
# Out:
# /var/folders/tb/ccwl9r592hn9v_xpq9s1bzlr0000gn/T/ipykernel_21837/2140094936.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   decoder.load_state_dict(torch.load(os.path.join(model_saves_dir, 'joint_decoder.pth'), map_location=cfg.device))
# <All keys matched successfully>

# %% [markdown]
# ## Load the BLL classifier

# %% [markdown]
# Define the MCMC model

# %%
from models.BLL import BayesianLastLayerCat
importlib.reload(models.BLL)

bll = BayesianLastLayerCat(
    backbone=backbone,
    input_dim=256,  # Matches backbone's encoder output
    output_dim=10,  # MNIST classes
    N_train=len(trainset),
    lr=0.001,
    base_C=1.0,
    gauss_sig=0.01,
    device=cfg.device
)

# %% [markdown]
# Load the MCMC model

# %%
bll.load_checkpoint(model_saves_dir + '/mnist_bll_models/BLL_MCMC_Joint_Decoder.pth')
# Out:
#  [load_checkpoint] Loaded checkpoint from ../model_saves/mnist_bll_models/BLL_MCMC_Joint_Decoder.pth
# /Users/conor/Documents/College terms/College/Thesis/Thesis_Code_Minimised/MyImplementation/models/BLL.py:313: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=self.device)

# %% [markdown]
# Define the VI model

# %%
from models.BLL_VI import BayesianLastLayerVI
importlib.reload(models.BLL_VI)

bll_vi = BayesianLastLayerVI(
    backbone=backbone,
    input_dim=256,
    output_dim=10,
    device=cfg.device  
)

# %% [markdown]
# Load the VI model

# %%
bll_vi.load_checkpoint(model_saves_dir + '/mnist_bll_vi_models/BLL_VI_Joint_Decoder.pt')
# Out:
#  [load_checkpoint] Loaded checkpoint from ../model_saves/mnist_bll_vi_models/BLL_VI_Joint_Decoder.pt
# /Users/conor/Documents/College terms/College/Thesis/Thesis_Code_Minimised/MyImplementation/models/BLL_VI.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=self.device)

# %% [markdown]
# ## Get uncertain images

# %% [markdown]
# Get the most uncertain images, we need a non-shuffled loader for this.

# %%
# Create a non-shuffled loader for uncertainty calculation
eval_loader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False, num_workers=2)

# Get uncertainty scores for all test set data points
uncertainties = []
indices = []

bll_vi.eval()
with torch.no_grad():
    for i, (images, _) in enumerate(eval_loader):
        images = images.to(cfg.device)
        # Get predictions and uncertainties using BLL model
        _, uncertainty_dict = bll.predict_with_uncertainty(images)
        
        # Store total uncertainties and indices
        uncertainties.extend(uncertainty_dict['total_entropy'].cpu().numpy())
        indices.extend(range(i*eval_loader.batch_size, min((i+1)*eval_loader.batch_size, len(testset))))

# Convert to numpy arrays
uncertainties = np.array(uncertainties)
indices = np.array(indices)

# Sort by uncertainty (descending order)
sorted_idx = np.argsort(-uncertainties)
sorted_uncertainties = uncertainties[sorted_idx]
sorted_data_indices = indices[sorted_idx]

# %% [markdown]
# We then plot the plot the most uncertain predictions on the test set.

# %%
import matplotlib.pyplot as plt
import torch

def plot_most_uncertain(testset, sorted_data_indices, sorted_uncertainties, n_plot=5):
    """
    Plots the top-n most uncertain predictions from the training set.

    Args:
        testset (torch.utils.data.Dataset): Dataset that returns (image, label) samples.
        sorted_data_indices (np.ndarray): Array of indices sorted in descending order by uncertainty.
        sorted_uncertainties (np.ndarray): Array of uncertainty (entropy) values, sorted to match sorted_data_indices.
        n_plot (int): Number of images to plot.
    """
    # Calculate number of rows needed
    images_per_row = 10
    n_rows = (n_plot - 1) // images_per_row + 1
    
    plt.figure(figsize=(15, 3 * n_rows))
    for i in range(n_plot):
        data_idx = sorted_data_indices[i]
        image, _ = testset[data_idx]
        
        # If image is a torch.Tensor, convert it to a NumPy array.
        if torch.is_tensor(image):
            image = image.cpu().detach().numpy()
            # If the image has one channel [1, H, W], squeeze out the channel dimension.
            if image.ndim == 3 and image.shape[0] == 1:
                image = image.squeeze(0)
        
        row = i // images_per_row
        col = i % images_per_row
        plt.subplot(n_rows, images_per_row, i + 1)
        plt.imshow(image, cmap='gray')
        plt.title(f"Entropy: {sorted_uncertainties[i]:.2f}")
        plt.axis("off")
    
    plt.suptitle("Most Uncertain Predictions")
    plt.show()

# %%
# Plot the most uncertain predictions
plot_most_uncertain(testset, sorted_data_indices, sorted_uncertainties, n_plot=20)

# %% [markdown]
# ## Test new CLUE implementation

# %% [markdown]
# Now we test the "new" CLUE implementation, which accepts only a classifier head, directly optimising the latent code. There is no need for a decoder at each step (and therefore inside the CLUE method).
# Once the latent code is optimised, we pass it through the decoder to get a reconstruction from this notebook.

# %% [markdown]
# ### Visualising

# %% [markdown]
# The first test is just with one image

# %%
# Get the most uncertain image and its latent representation
most_uncertain_idx = sorted_data_indices[2]
uncertain_image, true_label = testset[most_uncertain_idx]
uncertain_image = uncertain_image.to(cfg.device).unsqueeze(0)  # Add batch dimension

# Get its latent representation
bll.eval()
with torch.no_grad():
    z0 = bll.extract_features(uncertain_image)

# Initialize CLUE
clue = new_CLUE.NewCLUE(
    classifier=bll,
    z0=z0,
    uncertainty_weight=1.0,
    distance_weight=0.001,
    lr=0.1,
    device=cfg.device,
    bayesian=True,
    verbose=False
)

# Optimize to find explanation
z_explained = clue.optimize(steps=200)

# Generate reconstructions using decoder
with torch.no_grad():
    # Original reconstruction
    original_recon = decoder(z0)
    # CLUE reconstruction  
    clue_recon = decoder(z_explained)
    
    # Get predictions and uncertainties from latent codes
    original_probs_latent = bll.sample_predict_z(z0)  # [n_ensemble, batch, classes]
    explained_probs_latent = bll.sample_predict_z(z_explained)
    
    # Get predictions from full classifier workflow on reconstructions
    original_probs_recon = bll.sample_predict(original_recon)
    explained_probs_recon = bll.sample_predict(clue_recon)
    
    # Calculate mean probabilities and entropies for latent predictions
    original_mean_probs_latent = original_probs_latent.mean(dim=0)  # [batch, classes]
    explained_mean_probs_latent = explained_probs_latent.mean(dim=0)
    
    original_entropy_latent = -(original_mean_probs_latent * torch.log(original_mean_probs_latent + 1e-10)).sum(dim=1)
    explained_entropy_latent = -(explained_mean_probs_latent * torch.log(explained_mean_probs_latent + 1e-10)).sum(dim=1)
    
    # Calculate mean probabilities and entropies for reconstruction predictions
    original_mean_probs_recon = original_probs_recon.mean(dim=0)
    explained_mean_probs_recon = explained_probs_recon.mean(dim=0)
    
    original_entropy_recon = -(original_mean_probs_recon * torch.log(original_mean_probs_recon + 1e-10)).sum(dim=1)
    explained_entropy_recon = -(explained_mean_probs_recon * torch.log(explained_mean_probs_recon + 1e-10)).sum(dim=1)
    
    # Get predicted classes
    original_pred = original_mean_probs_recon.argmax(dim=1).item()
    explained_pred = explained_mean_probs_recon.argmax(dim=1).item()

# Plot results
plt.figure(figsize=(15, 10))

plt.subplot(231)
plt.imshow(uncertain_image[0,0].cpu(), cmap='gray')
plt.title(f'Original Image\nTrue Class: {true_label}, Predicted: {original_pred}\nEntropy: {original_entropy_recon[0]:.3f}')
plt.axis('off')

plt.subplot(232)
plt.imshow(clue_recon[0,0].cpu().detach(), cmap='gray')
plt.title(f'Counterfactual\nPredicted: {explained_pred}\nEntropy: {explained_entropy_recon[0]:.3f}')
plt.axis('off')

plt.subplot(233)
diff = clue_recon[0,0].cpu().detach() - uncertain_image[0,0].cpu()
plt.imshow(diff, cmap='RdBu', vmin=-1, vmax=1)  # Fixed scale -1 to 1
plt.title('Counterfactual vs Original\nDifference\n(Red: Added Features, Blue: Removed Features)')
plt.axis('off')

plt.subplot(234)
plt.imshow(original_recon[0,0].cpu().detach(), cmap='gray')
plt.title('Original Reconstruction')
plt.axis('off')

plt.subplot(235)
recon_diff = clue_recon[0,0].cpu().detach() - original_recon[0,0].cpu().detach()
plt.imshow(recon_diff, cmap='RdBu', vmin=-1, vmax=1)  # Fixed scale -1 to 1
plt.title('Counterfactual vs Original\nReconstruction Difference\n(Red: Added Features, Blue: Removed Features)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# And test determinsitic equivalent

# %%
# Get the most uncertain image and its latent representation
most_uncertain_idx = sorted_data_indices[2]
uncertain_image, true_label = testset[most_uncertain_idx]
uncertain_image = uncertain_image.to(cfg.device).unsqueeze(0)  # Add batch dimension

# Get its latent representation
backbone.eval()
with torch.no_grad():
    z0, _ = backbone(uncertain_image)

# Initialize CLUE
clue = new_CLUE.NewCLUE(
    classifier=backbone.classifier,  # Just use the classifier head
    z0=z0,
    uncertainty_weight=1.0,
    distance_weight=0.005,
    lr=0.1,
    device=cfg.device,
    bayesian=False,  # Non-Bayesian mode
    verbose=False
)

# Optimize to find explanation
z_explained = clue.optimize(steps=200)

# Generate reconstructions using decoder
with torch.no_grad():
    # Original reconstruction
    original_recon = decoder(z0)
    # CLUE reconstruction  
    clue_recon = decoder(z_explained)
    
    # Get predictions from classifier head
    original_logits = backbone.classifier(z0)
    explained_logits = backbone.classifier(z_explained)
    
    # Convert to probabilities
    original_probs = torch.nn.functional.softmax(original_logits, dim=1)
    explained_probs = torch.nn.functional.softmax(explained_logits, dim=1)
    
    # Get predictions from full classifier workflow on reconstructions
    _, original_recon_logits = backbone(original_recon)
    _, explained_recon_logits = backbone(clue_recon)
    
    original_recon_probs = torch.nn.functional.softmax(original_recon_logits, dim=1)
    explained_recon_probs = torch.nn.functional.softmax(explained_recon_logits, dim=1)
    
    # Calculate entropies for latent predictions
    original_entropy_latent = -(original_probs * torch.log(original_probs + 1e-10)).sum(dim=1)
    explained_entropy_latent = -(explained_probs * torch.log(explained_probs + 1e-10)).sum(dim=1)
    
    # Calculate entropies for reconstruction predictions
    original_entropy_recon = -(original_recon_probs * torch.log(original_recon_probs + 1e-10)).sum(dim=1)
    explained_entropy_recon = -(explained_recon_probs * torch.log(explained_recon_probs + 1e-10)).sum(dim=1)

    # Get predicted classes
    original_pred = original_recon_probs.argmax(dim=1).item()
    explained_pred = explained_recon_probs.argmax(dim=1).item()

# Plot results
plt.figure(figsize=(15, 10))

plt.subplot(231)
plt.imshow(uncertain_image[0,0].cpu(), cmap='gray')
plt.title(f'Original Image\nTrue Class: {true_label}, Predicted: {original_pred}\nEntropy: {original_entropy_recon[0]:.3f}')
plt.axis('off')

plt.subplot(232)
plt.imshow(clue_recon[0,0].cpu().detach(), cmap='gray')
plt.title(f'Counterfactual\nPredicted: {explained_pred}\nEntropy: {explained_entropy_recon[0]:.3f}')
plt.axis('off')

plt.subplot(233)
diff = clue_recon[0,0].cpu().detach() - uncertain_image[0,0].cpu()
plt.imshow(diff, cmap='RdBu', vmin=-1, vmax=1)  # Fixed scale -1 to 1
plt.title('Counterfactual vs Original\nDifference\n(Red: Removed Features, Blue: Added Features)')
plt.axis('off')

plt.subplot(234)
plt.imshow(original_recon[0,0].cpu().detach(), cmap='gray')
plt.title('Original Reconstruction')
plt.axis('off')

plt.subplot(235)
recon_diff = clue_recon[0,0].cpu().detach() - original_recon[0,0].cpu().detach()
plt.imshow(recon_diff, cmap='RdBu', vmin=-1, vmax=1)  # Fixed scale -1 to 1
plt.title('Counterfactual vs Original\nReconstruction Difference\n(Red: Removed Features, Blue: Added Features)')
plt.axis('off')

plt.tight_layout()
plt.show()

# Print probabilities
print("\nClass probabilities:")
print(f"Original (True class: {true_label}, Predicted: {original_pred}):", original_recon_probs.cpu().numpy()[0].round(3))
print(f"Explained (Predicted: {explained_pred}):", explained_recon_probs.cpu().numpy()[0].round(3))
# Out:
# Class probabilities:
# Original (True class: 7, Predicted: 9): [0.009 0.145 0.    0.    0.    0.    0.    0.283 0.006 0.558]
# Explained (Predicted: 7): [0.003 0.091 0.    0.    0.    0.    0.    0.762 0.001 0.142]

# %% [markdown]
# And the BLL VI

# %%
# Get the most uncertain image and its latent representation
most_uncertain_idx = sorted_data_indices[2]
uncertain_image, _ = testset[most_uncertain_idx]
uncertain_image = uncertain_image.to(cfg.device).unsqueeze(0)  # Add batch dimension

# Get its latent representation
bll.eval()
with torch.no_grad():
    z0 = bll_vi.extract_features(uncertain_image)

# Initialize CLUE
clue = new_CLUE.NewCLUE(
    classifier=bll_vi,
    z0=z0,
    uncertainty_weight=1.0,
    distance_weight=0.005,
    lr=0.1,
    device=cfg.device,
    bayesian=True,
    verbose=False
)

# Optimize to find explanation
z_explained = clue.optimize(steps=200)

# Generate reconstructions using decoder
with torch.no_grad():
    # Original reconstruction
    original_recon = decoder(z0)
    # CLUE reconstruction  
    clue_recon = decoder(z_explained)
    
    # Get predictions and uncertainties from latent codes
    original_probs_latent = bll_vi.sample_predict_z(z0)  # [n_ensemble, batch, classes]
    explained_probs_latent = bll_vi.sample_predict_z(z_explained)
    
    # Get predictions from full classifier workflow on reconstructions
    original_probs_recon = bll_vi.sample_predict(original_recon)
    explained_probs_recon = bll_vi.sample_predict(clue_recon)
    
    # Calculate mean probabilities and entropies for latent predictions
    original_mean_probs_latent = original_probs_latent.mean(dim=0)  # [batch, classes]
    explained_mean_probs_latent = explained_probs_latent.mean(dim=0)
    
    original_entropy_latent = -(original_mean_probs_latent * torch.log(original_mean_probs_latent + 1e-10)).sum(dim=1)
    explained_entropy_latent = -(explained_mean_probs_latent * torch.log(explained_mean_probs_latent + 1e-10)).sum(dim=1)
    
    # Calculate mean probabilities and entropies for reconstruction predictions
    original_mean_probs_recon = original_probs_recon.mean(dim=0)
    explained_mean_probs_recon = explained_probs_recon.mean(dim=0)
    
    original_entropy_recon = -(original_mean_probs_recon * torch.log(original_mean_probs_recon + 1e-10)).sum(dim=1)
    explained_entropy_recon = -(explained_mean_probs_recon * torch.log(explained_mean_probs_recon + 1e-10)).sum(dim=1)

    # Get predicted classes
    original_pred = original_mean_probs_recon.argmax(dim=1).item()
    explained_pred = explained_mean_probs_recon.argmax(dim=1).item()

# Plot results
plt.figure(figsize=(15, 10))

plt.subplot(231)
plt.imshow(uncertain_image[0,0].cpu(), cmap='gray')
plt.title(f'Original Image\nPredicted: {original_pred}\nEntropy: {original_entropy_recon[0]:.3f}')
plt.axis('off')

plt.subplot(232)
plt.imshow(clue_recon[0,0].cpu().detach(), cmap='gray')
plt.title(f'Counterfactual\nPredicted: {explained_pred}\nEntropy: {explained_entropy_recon[0]:.3f}')
plt.axis('off')

plt.subplot(233)
diff = clue_recon[0,0].cpu().detach() - uncertain_image[0,0].cpu()
plt.imshow(diff, cmap='RdBu', vmin=-1, vmax=1)  # Fixed scale -1 to 1
plt.title('Counterfactual vs Original\nDifference\n(Red: Removed Features, Blue: Added Features)')
plt.axis('off')

plt.subplot(234)
plt.imshow(original_recon[0,0].cpu().detach(), cmap='gray')
plt.title('Original Reconstruction')
plt.axis('off')

plt.subplot(235)
recon_diff = clue_recon[0,0].cpu().detach() - original_recon[0,0].cpu().detach()
plt.imshow(recon_diff, cmap='RdBu', vmin=-1, vmax=1)  # Fixed scale -1 to 1
plt.title('Counterfactual vs Original\nReconstruction Difference\n(Red: Removed Features, Blue: Added Features)')
plt.axis('off')

plt.tight_layout()
plt.show()

# Print probabilities
print("\nClass probabilities:")
print("Original tensor:", original_mean_probs_recon)
print(f"Original (True class: {true_label}, Predicted: {original_pred}):", original_mean_probs_recon.cpu().numpy()[0].round(3))
print("Explained tensor:", explained_mean_probs_recon)
print(f"Explained (Predicted: {explained_pred}):", explained_mean_probs_recon.cpu().numpy()[0].round(3))
# Print probabilities
print("\nClass probabilities:")
print(f"Original (True class: {true_label}, Predicted: {original_pred}):", original_recon_probs.cpu().numpy()[0].round(3))
print(f"Explained (Predicted: {explained_pred}):", explained_recon_probs.cpu().numpy()[0].round(3))
# Out:
# Prediction details:
# Original probabilities shape: torch.Size([1, 10])
# Original argmax result: tensor([9], device='mps:0')
# Explained probabilities shape: torch.Size([1, 10])
# Explained argmax result: tensor([0], device='mps:0')
#
# Class probabilities:
# Original (True class: 7, Predicted: 9): [0.009 0.145 0.    0.    0.    0.    0.    0.283 0.006 0.558]
# Explained (Predicted: 0): [0.003 0.091 0.    0.    0.    0.    0.    0.762 0.001 0.142]

# %% [markdown]
# Below, we plot the t-SNE of the latent space of the test set. We can see that the optimised latent code is close to the original latent code, but not identical.

# %%
# Get latent codes for 500 training images to create TSNE visualization
latent_codes = []
labels_list = []
with torch.no_grad():
    for i, (images, labels) in enumerate(testloader):
        if i >= 500/images.shape[0]:  # Stop after ~500 images
            break
        images = images.to(cfg.device)
        z = bll_vi.extract_features(images)  # Use bll_vi.extract_features instead of backbone
        latent_codes.append(z.cpu())
        labels_list.append(labels)
latent_codes = torch.cat(latent_codes, dim=0)
labels = torch.cat(labels_list, dim=0)

# Get latent code of reconstructed counterfactual
with torch.no_grad():
    z_recon = bll_vi.extract_features(clue_recon)

# Add z0, z_explained and z_recon to the latent codes
all_latents = torch.cat([latent_codes, z0.cpu(), z_explained.cpu(), z_recon.cpu()], dim=0)

# Perform t-SNE
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=42)
latents_2d = tsne.fit_transform(all_latents.numpy())

# Plot t-SNE
plt.figure(figsize=(10, 8))

# Create scatter plot for each class
testing_latents_2d = latents_2d[:-3]
for i in range(10):
    mask = labels == i
    plt.scatter(testing_latents_2d[mask, 0], testing_latents_2d[mask, 1], 
               alpha=0.5, label=f'Class {i}', s=20)  # Reduced point size to 20

# Plot original, explained and reconstructed points
plt.scatter(latents_2d[-3, 0], latents_2d[-3, 1], c='black', s=10, label='Original (z0)')
plt.scatter(latents_2d[-2, 0], latents_2d[-2, 1], c='red', s=10, label='Explained (z)')
plt.scatter(latents_2d[-1, 0], latents_2d[-1, 1], c='blue', s=10, label='Reconstructed (z_recon)')

# Calculate and print distances between points in t-SNE space
tsne_distance_orig_exp = np.sqrt(np.sum((latents_2d[-3] - latents_2d[-2])**2))
tsne_distance_exp_recon = np.sqrt(np.sum((latents_2d[-2] - latents_2d[-1])**2))
print(f"\nDistance between original and explained points in t-SNE space: {tsne_distance_orig_exp:.3f}")
print(f"Distance between explained and reconstructed points in t-SNE space: {tsne_distance_exp_recon:.3f}")

plt.title('t-SNE visualization of latent space')
plt.legend()
plt.show()
# Out:
# Distance between original and explained points in t-SNE space: 0.253
# Distance between explained and reconstructed points in t-SNE space: 0.203

# %% [markdown]
# ### Comparing metrics between Bayesian and Deterministic Last Layer

# %% [markdown]
# Test on the MCMC BLL

# %%
# Get 50 most uncertain images
uncertain_indices = sorted_data_indices[:50]

# Initialize lists to store metrics
latent_entropy_reductions = []
recon_entropy_reductions = []
distances = []

# Process each uncertain image
for idx in uncertain_indices:
    uncertain_image, _ = testset[idx]
    uncertain_image = uncertain_image.to(cfg.device).unsqueeze(0)  # Add batch dimension

    # Get latent representation
    bll.eval()
    with torch.no_grad():
        z0 = bll.extract_features(uncertain_image)

    # Initialize CLUE
    clue = new_CLUE.NewCLUE(
        classifier=bll,
        z0=z0,
        uncertainty_weight=1.0,
        distance_weight=0.005,
        lr=0.1,
        device=cfg.device,
        bayesian=True
    )

    # Optimize to find explanation
    z_explained = clue.optimize(steps=200)

    # Calculate distance between original and explained latent codes
    distance = torch.norm(z0 - z_explained).item()
    distances.append(distance)

    # Generate reconstructions using decoder
    with torch.no_grad():
        # Original reconstruction
        original_recon = decoder(z0)
        # CLUE reconstruction  
        clue_recon = decoder(z_explained)
        
        # Get predictions and uncertainties from latent codes
        original_probs_latent = bll.sample_predict_z(z0)
        explained_probs_latent = bll.sample_predict_z(z_explained)
        
        # Get predictions from full classifier workflow on reconstructions
        original_probs_recon = bll.sample_predict(original_recon)
        explained_probs_recon = bll.sample_predict(clue_recon)
        
        # Calculate mean probabilities and entropies for latent predictions
        original_mean_probs_latent = original_probs_latent.mean(dim=0)
        explained_mean_probs_latent = explained_probs_latent.mean(dim=0)
        
        original_entropy_latent = -(original_mean_probs_latent * torch.log(original_mean_probs_latent + 1e-10)).sum(dim=1)
        explained_entropy_latent = -(explained_mean_probs_latent * torch.log(explained_mean_probs_latent + 1e-10)).sum(dim=1)
        
        # Calculate mean probabilities and entropies for reconstruction predictions
        original_mean_probs_recon = original_probs_recon.mean(dim=0)
        explained_mean_probs_recon = explained_probs_recon.mean(dim=0)
        
        original_entropy_recon = -(original_mean_probs_recon * torch.log(original_mean_probs_recon + 1e-10)).sum(dim=1)
        explained_entropy_recon = -(explained_mean_probs_recon * torch.log(explained_mean_probs_recon + 1e-10)).sum(dim=1)

        # Calculate entropy reductions
        latent_entropy_reduction = (original_entropy_latent - explained_entropy_latent).item()
        recon_entropy_reduction = (original_entropy_recon - explained_entropy_recon).item()
        
        latent_entropy_reductions.append(latent_entropy_reduction)
        recon_entropy_reductions.append(recon_entropy_reduction)

# Calculate averages
avg_latent_entropy_reduction = np.mean(latent_entropy_reductions)
avg_recon_entropy_reduction = np.mean(recon_entropy_reductions)
avg_distance = np.mean(distances)

print(f"\nResults over {len(uncertain_indices)} most uncertain images:")
print(f"Average latent entropy reduction: {avg_latent_entropy_reduction:.3f}")
print(f"Average reconstruction entropy reduction: {avg_recon_entropy_reduction:.3f}")
print(f"Average distance between original and explained latents: {avg_distance:.3f}")
# Out:
# Step 00: Loss: 1.7058, Total Entropy: 1.7058, Epistemic Entropy: 0.0355, Aleatoric Entropy: 1.6703, Distance: 0.0000
# Step 01: Loss: 1.0065, Total Entropy: 0.9985, Epistemic Entropy: 0.0204, Aleatoric Entropy: 0.9782, Distance: 1.6000
# Step 02: Loss: 0.2621, Total Entropy: 0.2484, Epistemic Entropy: 0.0034, Aleatoric Entropy: 0.2449, Distance: 2.7443
# Step 03: Loss: 0.0590, Total Entropy: 0.0393, Epistemic Entropy: 0.0003, Aleatoric Entropy: 0.0390, Distance: 3.9371
# Step 04: Loss: 0.0322, Total Entropy: 0.0073, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0072, Distance: 4.9978
# Step 05: Loss: 0.0312, Total Entropy: 0.0017, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0017, Distance: 5.9131
# Step 06: Loss: 0.0340, Total Entropy: 0.0005, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0005, Distance: 6.7045
# Step 07: Loss: 0.0371, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 7.3933
# Step 08: Loss: 0.0400, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 7.9963
# Step 09: Loss: 0.0427, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.5264
# Step 10: Loss: 0.0450, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.9941
# Step 11: Loss: 0.0470, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.4074
# Step 12: Loss: 0.0489, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.7730
# Step 13: Loss: 0.0505, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.0967
# Step 14: Loss: 0.0519, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.3829
# Step 15: Loss: 0.0532, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.6359
# Step 16: Loss: 0.0543, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.8589
# Step 17: Loss: 0.0553, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.0550
# Step 18: Loss: 0.0561, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.2269
# Step 19: Loss: 0.0569, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.3768
# Step 20: Loss: 0.0575, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.5068
# Step 21: Loss: 0.0581, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.6187
# Step 22: Loss: 0.0586, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7142
# Step 23: Loss: 0.0590, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7947
# Step 24: Loss: 0.0593, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.8615
# Step 25: Loss: 0.0596, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.9159
# Step 26: Loss: 0.0598, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.9590
# Step 27: Loss: 0.0600, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.9917
# Step 28: Loss: 0.0601, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 12.0149
# Step 29: Loss: 0.0601, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 12.0294
# Step 30: Loss: 0.0602, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 12.0360
# Step 31: Loss: 0.0602, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 12.0354
# Step 32: Loss: 0.0601, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 12.0281
# Step 33: Loss: 0.0601, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 12.0147
# Step 34: Loss: 0.0600, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.9958
# Step 35: Loss: 0.0599, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.9718
# Step 36: Loss: 0.0597, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.9431
# Step 37: Loss: 0.0596, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.9102
# Step 38: Loss: 0.0594, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.8733
# Step 39: Loss: 0.0592, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.8329
# Step 40: Loss: 0.0589, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7892
# Step 41: Loss: 0.0587, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7425
# Step 42: Loss: 0.0585, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.6930
# Step 43: Loss: 0.0582, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.6411
# Step 44: Loss: 0.0579, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.5868
# Step 45: Loss: 0.0577, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.5305
# Step 46: Loss: 0.0574, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.4722
# Step 47: Loss: 0.0571, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.4121
# Step 48: Loss: 0.0568, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.3505
# Step 49: Loss: 0.0564, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.2873
# Step 50: Loss: 0.0561, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.2229
# Step 51: Loss: 0.0558, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.1571
# Step 52: Loss: 0.0555, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.0903
# Step 53: Loss: 0.0551, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.0224
# Step 54: Loss: 0.0548, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.9535
# Step 55: Loss: 0.0544, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.8838
# Step 56: Loss: 0.0541, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.8133
# Step 57: Loss: 0.0537, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.7421
# Step 58: Loss: 0.0534, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.6702
# Step 59: Loss: 0.0530, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.5977
# Step 60: Loss: 0.0526, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.5247
# Step 61: Loss: 0.0523, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.4511
# Step 62: Loss: 0.0519, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.3771
# Step 63: Loss: 0.0515, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.3026
# Step 64: Loss: 0.0511, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.2278
# Step 65: Loss: 0.0508, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.1526
# Step 66: Loss: 0.0504, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.0771
# Step 67: Loss: 0.0500, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.0014
# Step 68: Loss: 0.0496, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.9253
# Step 69: Loss: 0.0492, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.8490
# Step 70: Loss: 0.0489, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.7725
# Step 71: Loss: 0.0485, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.6958
# Step 72: Loss: 0.0481, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 9.6189
# Step 73: Loss: 0.0477, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 9.5419
# Step 74: Loss: 0.0473, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 9.4647
# Step 75: Loss: 0.0469, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 9.3874
# Step 76: Loss: 0.0466, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 9.3099
# Step 77: Loss: 0.0462, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.2324
# Step 78: Loss: 0.0458, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.1548
# Step 79: Loss: 0.0454, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.0771
# Step 80: Loss: 0.0450, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.9993
# Step 81: Loss: 0.0446, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.9215
# Step 82: Loss: 0.0442, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.8437
# Step 83: Loss: 0.0438, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.7658
# Step 84: Loss: 0.0434, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.6879
# Step 85: Loss: 0.0431, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 8.6100
# Step 86: Loss: 0.0427, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.5320
# Step 87: Loss: 0.0423, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.4541
# Step 88: Loss: 0.0419, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.3762
# Step 89: Loss: 0.0415, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 8.2982
# Step 90: Loss: 0.0411, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.2204
# Step 91: Loss: 0.0407, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.1425
# Step 92: Loss: 0.0403, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.0647
# Step 93: Loss: 0.0399, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.9869
# Step 94: Loss: 0.0396, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.9092
# Step 95: Loss: 0.0392, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.8315
# Step 96: Loss: 0.0388, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.7539
# Step 97: Loss: 0.0384, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.6764
# Step 98: Loss: 0.0380, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.5990
# Step 99: Loss: 0.0376, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.5216
# Step 100: Loss: 0.0373, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.4444
# Step 101: Loss: 0.0369, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.3673
# Step 102: Loss: 0.0365, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.2902
# Step 103: Loss: 0.0361, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.2134
# Step 104: Loss: 0.0357, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.1366
# Step 105: Loss: 0.0354, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 7.0600
# Step 106: Loss: 0.0350, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.9836
# Step 107: Loss: 0.0346, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.9074
# Step 108: Loss: 0.0342, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.8313
# Step 109: Loss: 0.0339, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.7555
# Step 110: Loss: 0.0335, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.6799
# Step 111: Loss: 0.0331, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.6045
# Step 112: Loss: 0.0328, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.5294
# Step 113: Loss: 0.0324, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.4546
# Step 114: Loss: 0.0321, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 6.3801
# Step 115: Loss: 0.0317, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 6.3060
# Step 116: Loss: 0.0314, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 6.2322
# Step 117: Loss: 0.0310, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 6.1589
# Step 118: Loss: 0.0307, Total Entropy: 0.0003, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0003, Distance: 6.0860
# Step 119: Loss: 0.0304, Total Entropy: 0.0003, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0003, Distance: 6.0136
# Step 120: Loss: 0.0300, Total Entropy: 0.0003, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0003, Distance: 5.9418
# Step 121: Loss: 0.0297, Total Entropy: 0.0004, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0004, Distance: 5.8706
# Step 122: Loss: 0.0294, Total Entropy: 0.0004, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0004, Distance: 5.8000
# Step 123: Loss: 0.0291, Total Entropy: 0.0005, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0005, Distance: 5.7302
# Step 124: Loss: 0.0289, Total Entropy: 0.0005, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0005, Distance: 5.6612
# Step 125: Loss: 0.0286, Total Entropy: 0.0006, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0006, Distance: 5.5931
# Step 126: Loss: 0.0283, Total Entropy: 0.0007, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0007, Distance: 5.5260
# Step 127: Loss: 0.0281, Total Entropy: 0.0008, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0008, Distance: 5.4600
# Step 128: Loss: 0.0278, Total Entropy: 0.0009, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0009, Distance: 5.3951
# Step 129: Loss: 0.0276, Total Entropy: 0.0010, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0010, Distance: 5.3316
# Step 130: Loss: 0.0274, Total Entropy: 0.0011, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0011, Distance: 5.2695
# Step 131: Loss: 0.0272, Total Entropy: 0.0012, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0012, Distance: 5.2089
# Step 132: Loss: 0.0271, Total Entropy: 0.0013, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0013, Distance: 5.1501
# Step 133: Loss: 0.0269, Total Entropy: 0.0014, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0014, Distance: 5.0932
# Step 134: Loss: 0.0268, Total Entropy: 0.0016, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0016, Distance: 5.0382
# Step 135: Loss: 0.0267, Total Entropy: 0.0017, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0017, Distance: 4.9855
# Step 136: Loss: 0.0266, Total Entropy: 0.0019, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0019, Distance: 4.9351
# Step 137: Loss: 0.0265, Total Entropy: 0.0020, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0020, Distance: 4.8872
# Step 138: Loss: 0.0264, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0022, Distance: 4.8419
# Step 139: Loss: 0.0264, Total Entropy: 0.0024, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0023, Distance: 4.7996
# Step 140: Loss: 0.0263, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 4.7601
# Step 141: Loss: 0.0263, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.7238
# Step 142: Loss: 0.0263, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6906
# Step 143: Loss: 0.0263, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6608
# Step 144: Loss: 0.0263, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6343
# Step 145: Loss: 0.0262, Total Entropy: 0.0032, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0032, Distance: 4.6111
# Step 146: Loss: 0.0262, Total Entropy: 0.0033, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0033, Distance: 4.5913
# Step 147: Loss: 0.0262, Total Entropy: 0.0034, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0033, Distance: 4.5748
# Step 148: Loss: 0.0262, Total Entropy: 0.0034, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0034, Distance: 4.5616
# Step 149: Loss: 0.0262, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 4.5513
# Step 150: Loss: 0.0262, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 4.5441
# Step 151: Loss: 0.0262, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 4.5395
# Step 152: Loss: 0.0262, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 4.5374
# Step 153: Loss: 0.0262, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 4.5376
# Step 154: Loss: 0.0262, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 4.5399
# Step 155: Loss: 0.0262, Total Entropy: 0.0034, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0034, Distance: 4.5438
# Step 156: Loss: 0.0261, Total Entropy: 0.0034, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0034, Distance: 4.5492
# Step 157: Loss: 0.0261, Total Entropy: 0.0033, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0033, Distance: 4.5558
# Step 158: Loss: 0.0261, Total Entropy: 0.0033, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0033, Distance: 4.5634
# Step 159: Loss: 0.0261, Total Entropy: 0.0032, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0032, Distance: 4.5716
# Step 160: Loss: 0.0261, Total Entropy: 0.0032, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0032, Distance: 4.5802
# Step 161: Loss: 0.0261, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.5891
# Step 162: Loss: 0.0261, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.5979
# Step 163: Loss: 0.0261, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6067
# Step 164: Loss: 0.0261, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6151
# Step 165: Loss: 0.0261, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6230
# Step 166: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6304
# Step 167: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6372
# Step 168: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6433
# Step 169: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6487
# Step 170: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6533
# Step 171: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6572
# Step 172: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6602
# Step 173: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6626
# Step 174: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6642
# Step 175: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6651
# Step 176: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6654
# Step 177: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6652
# Step 178: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6644
# Step 179: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6631
# Step 180: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6615
# Step 181: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6594
# Step 182: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6572
# Step 183: Loss: 0.0260, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6546
# Step 184: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.6520
# Step 185: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6492
# Step 186: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6464
# Step 187: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6435
# Step 188: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6408
# Step 189: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6380
# Step 190: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6354
# Step 191: Loss: 0.0260, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6330
# Step 192: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.6307
# Step 193: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6286
# Step 194: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6267
# Step 195: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6251
# Step 196: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6236
# Step 197: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6224
# Step 198: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6214
# Step 199: Loss: 0.0260, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6206
# Step 00: Loss: 1.5581, Total Entropy: 1.5581, Epistemic Entropy: 0.0118, Aleatoric Entropy: 1.5463, Distance: 0.0000
# Step 01: Loss: 0.6030, Total Entropy: 0.5950, Epistemic Entropy: 0.0061, Aleatoric Entropy: 0.5889, Distance: 1.6000
# Step 02: Loss: 0.1239, Total Entropy: 0.1090, Epistemic Entropy: 0.0011, Aleatoric Entropy: 0.1079, Distance: 2.9875
# Step 03: Loss: 0.0417, Total Entropy: 0.0206, Epistemic Entropy: 0.0002, Aleatoric Entropy: 0.0204, Distance: 4.2295
# Step 04: Loss: 0.0313, Total Entropy: 0.0049, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0049, Distance: 5.2799
# Step 05: Loss: 0.0323, Total Entropy: 0.0015, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0014, Distance: 6.1702
# Step 06: Loss: 0.0352, Total Entropy: 0.0005, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0005, Distance: 6.9328
# Step 07: Loss: 0.0382, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 7.5919
# Step 08: Loss: 0.0409, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 8.1653
# Step 09: Loss: 0.0434, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.6667
# Step 10: Loss: 0.0456, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.1063
# Step 11: Loss: 0.0475, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.4926
# Step 12: Loss: 0.0492, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.8322
# Step 13: Loss: 0.0507, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.1307
# Step 14: Loss: 0.0520, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.3929
# Step 15: Loss: 0.0531, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.6226
# Step 16: Loss: 0.0541, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.8234
# Step 17: Loss: 0.0550, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.9981
# Step 18: Loss: 0.0557, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 11.1494
# Step 19: Loss: 0.0564, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 11.2796
# Step 20: Loss: 0.0570, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 11.3907
# Step 21: Loss: 0.0574, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 11.4844
# Step 22: Loss: 0.0578, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.5625
# Step 23: Loss: 0.0581, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.6262
# Step 24: Loss: 0.0584, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.6770
# Step 25: Loss: 0.0586, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7160
# Step 26: Loss: 0.0587, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7443
# Step 27: Loss: 0.0588, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7627
# Step 28: Loss: 0.0589, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7721
# Step 29: Loss: 0.0589, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7734
# Step 30: Loss: 0.0588, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7672
# Step 31: Loss: 0.0588, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7542
# Step 32: Loss: 0.0587, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7350
# Step 33: Loss: 0.0586, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.7100
# Step 34: Loss: 0.0584, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.6799
# Step 35: Loss: 0.0582, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.6449
# Step 36: Loss: 0.0580, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.6056
# Step 37: Loss: 0.0578, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.5623
# Step 38: Loss: 0.0576, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.5154
# Step 39: Loss: 0.0573, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.4651
# Step 40: Loss: 0.0571, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.4118
# Step 41: Loss: 0.0568, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.3557
# Step 42: Loss: 0.0565, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.2971
# Step 43: Loss: 0.0562, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.2361
# Step 44: Loss: 0.0559, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.1731
# Step 45: Loss: 0.0555, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.1082
# Step 46: Loss: 0.0552, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 11.0415
# Step 47: Loss: 0.0549, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.9732
# Step 48: Loss: 0.0545, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.9035
# Step 49: Loss: 0.0542, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.8325
# Step 50: Loss: 0.0538, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.7603
# Step 51: Loss: 0.0534, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.6870
# Step 52: Loss: 0.0531, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 10.6127
# Step 53: Loss: 0.0527, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.5376
# Step 54: Loss: 0.0523, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.4616
# Step 55: Loss: 0.0519, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.3849
# Step 56: Loss: 0.0515, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.3075
# Step 57: Loss: 0.0511, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.2295
# Step 58: Loss: 0.0508, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.1509
# Step 59: Loss: 0.0504, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 10.0718
# Step 60: Loss: 0.0500, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 9.9923
# Step 61: Loss: 0.0496, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.9123
# Step 62: Loss: 0.0492, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.8319
# Step 63: Loss: 0.0488, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.7512
# Step 64: Loss: 0.0484, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.6701
# Step 65: Loss: 0.0479, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.5888
# Step 66: Loss: 0.0475, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.5072
# Step 67: Loss: 0.0471, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.4253
# Step 68: Loss: 0.0467, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.3433
# Step 69: Loss: 0.0463, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 9.2610
# Step 70: Loss: 0.0459, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 9.1786
# Step 71: Loss: 0.0455, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.0961
# Step 72: Loss: 0.0451, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 9.0134
# Step 73: Loss: 0.0447, Total Entropy: 0.0000, Epistemic Entropy: -0.0000, Aleatoric Entropy: 0.0000, Distance: 8.9306
# Step 74: Loss: 0.0442, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.8477
# Step 75: Loss: 0.0438, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.7647
# Step 76: Loss: 0.0434, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.6817
# Step 77: Loss: 0.0430, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.5986
# Step 78: Loss: 0.0426, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.5155
# Step 79: Loss: 0.0422, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.4323
# Step 80: Loss: 0.0418, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.3492
# Step 81: Loss: 0.0413, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.2660
# Step 82: Loss: 0.0409, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.1829
# Step 83: Loss: 0.0405, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.0998
# Step 84: Loss: 0.0401, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 8.0168
# Step 85: Loss: 0.0397, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.9338
# Step 86: Loss: 0.0393, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.8508
# Step 87: Loss: 0.0389, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.7680
# Step 88: Loss: 0.0385, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.6852
# Step 89: Loss: 0.0381, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.6026
# Step 90: Loss: 0.0376, Total Entropy: 0.0000, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0000, Distance: 7.5200
# Step 91: Loss: 0.0372, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 7.4376
# Step 92: Loss: 0.0368, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 7.3553
# Step 93: Loss: 0.0364, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 7.2732
# Step 94: Loss: 0.0360, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 7.1912
# Step 95: Loss: 0.0356, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 7.1094
# Step 96: Loss: 0.0352, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 7.0279
# Step 97: Loss: 0.0348, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.9465
# Step 98: Loss: 0.0344, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.8654
# Step 99: Loss: 0.0341, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.7846
# Step 100: Loss: 0.0337, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 6.7040
# Step 101: Loss: 0.0333, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 6.6238
# Step 102: Loss: 0.0329, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 6.5439
# Step 103: Loss: 0.0325, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 6.4644
# Step 104: Loss: 0.0322, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 6.3853
# Step 105: Loss: 0.0318, Total Entropy: 0.0003, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0003, Distance: 6.3066
# Step 106: Loss: 0.0314, Total Entropy: 0.0003, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0003, Distance: 6.2284
# Step 107: Loss: 0.0311, Total Entropy: 0.0003, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0003, Distance: 6.1507
# Step 108: Loss: 0.0307, Total Entropy: 0.0004, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0004, Distance: 6.0737
# Step 109: Loss: 0.0304, Total Entropy: 0.0004, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0004, Distance: 5.9972
# Step 110: Loss: 0.0301, Total Entropy: 0.0005, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0005, Distance: 5.9215
# Step 111: Loss: 0.0298, Total Entropy: 0.0005, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0005, Distance: 5.8466
# Step 112: Loss: 0.0295, Total Entropy: 0.0006, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0006, Distance: 5.7725
# Step 113: Loss: 0.0292, Total Entropy: 0.0007, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0007, Distance: 5.6994
# Step 114: Loss: 0.0289, Total Entropy: 0.0007, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0007, Distance: 5.6273
# Step 115: Loss: 0.0286, Total Entropy: 0.0008, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0008, Distance: 5.5564
# Step 116: Loss: 0.0284, Total Entropy: 0.0009, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0009, Distance: 5.4867
# Step 117: Loss: 0.0281, Total Entropy: 0.0010, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0010, Distance: 5.4185
# Step 118: Loss: 0.0279, Total Entropy: 0.0011, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0011, Distance: 5.3517
# Step 119: Loss: 0.0277, Total Entropy: 0.0013, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0013, Distance: 5.2866
# Step 120: Loss: 0.0275, Total Entropy: 0.0014, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0014, Distance: 5.2233
# Step 121: Loss: 0.0274, Total Entropy: 0.0015, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0015, Distance: 5.1619
# Step 122: Loss: 0.0272, Total Entropy: 0.0017, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0017, Distance: 5.1027
# Step 123: Loss: 0.0271, Total Entropy: 0.0019, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0018, Distance: 5.0458
# Step 124: Loss: 0.0270, Total Entropy: 0.0020, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0020, Distance: 4.9914
# Step 125: Loss: 0.0269, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0022, Distance: 4.9397
# Step 126: Loss: 0.0268, Total Entropy: 0.0024, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0023, Distance: 4.8908
# Step 127: Loss: 0.0268, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 4.8448
# Step 128: Loss: 0.0267, Total Entropy: 0.0027, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 4.8021
# Step 129: Loss: 0.0267, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0028, Distance: 4.7626
# Step 130: Loss: 0.0267, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.7265
# Step 131: Loss: 0.0267, Total Entropy: 0.0032, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0032, Distance: 4.6940
# Step 132: Loss: 0.0267, Total Entropy: 0.0033, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0033, Distance: 4.6650
# Step 133: Loss: 0.0267, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0034, Distance: 4.6397
# Step 134: Loss: 0.0267, Total Entropy: 0.0036, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 4.6180
# Step 135: Loss: 0.0267, Total Entropy: 0.0037, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0036, Distance: 4.5998
# Step 136: Loss: 0.0267, Total Entropy: 0.0037, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0037, Distance: 4.5851
# Step 137: Loss: 0.0267, Total Entropy: 0.0038, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0038, Distance: 4.5738
# Step 138: Loss: 0.0266, Total Entropy: 0.0038, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0038, Distance: 4.5656
# Step 139: Loss: 0.0266, Total Entropy: 0.0038, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0038, Distance: 4.5605
# Step 140: Loss: 0.0266, Total Entropy: 0.0038, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0038, Distance: 4.5581
# Step 141: Loss: 0.0266, Total Entropy: 0.0038, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0038, Distance: 4.5583
# Step 142: Loss: 0.0266, Total Entropy: 0.0038, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0038, Distance: 4.5606
# Step 143: Loss: 0.0266, Total Entropy: 0.0038, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0037, Distance: 4.5650
# Step 144: Loss: 0.0266, Total Entropy: 0.0037, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0037, Distance: 4.5709
# Step 145: Loss: 0.0266, Total Entropy: 0.0037, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0036, Distance: 4.5782
# Step 146: Loss: 0.0265, Total Entropy: 0.0036, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0036, Distance: 4.5866
# Step 147: Loss: 0.0265, Total Entropy: 0.0036, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 4.5958
# Step 148: Loss: 0.0265, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 4.6055
# Step 149: Loss: 0.0265, Total Entropy: 0.0034, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0034, Distance: 4.6155
# Step 150: Loss: 0.0265, Total Entropy: 0.0034, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0033, Distance: 4.6255
# Step 151: Loss: 0.0265, Total Entropy: 0.0033, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0033, Distance: 4.6354
# Step 152: Loss: 0.0265, Total Entropy: 0.0033, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0032, Distance: 4.6450
# Step 153: Loss: 0.0265, Total Entropy: 0.0032, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0032, Distance: 4.6542
# Step 154: Loss: 0.0265, Total Entropy: 0.0032, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6628
# Step 155: Loss: 0.0265, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6707
# Step 156: Loss: 0.0265, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6779
# Step 157: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6843
# Step 158: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6898
# Step 159: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6946
# Step 160: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6985
# Step 161: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.7015
# Step 162: Loss: 0.0265, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.7038
# Step 163: Loss: 0.0265, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.7054
# Step 164: Loss: 0.0265, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.7062
# Step 165: Loss: 0.0265, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.7064
# Step 166: Loss: 0.0265, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.7060
# Step 167: Loss: 0.0265, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.7051
# Step 168: Loss: 0.0265, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.7036
# Step 169: Loss: 0.0265, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.7018
# Step 170: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6997
# Step 171: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 4.6973
# Step 172: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6947
# Step 173: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6919
# Step 174: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6891
# Step 175: Loss: 0.0265, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6862
# Step 176: Loss: 0.0264, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6833
# Step 177: Loss: 0.0264, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6805
# Step 178: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6778
# Step 179: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 4.6753
# Step 180: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6729
# Step 181: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6706
# Step 182: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6686
# Step 183: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6668
# Step 184: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6653
# Step 185: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6639
# Step 186: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6628
# Step 187: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6619
# Step 188: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6612
# Step 189: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6608
# Step 190: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6605
# Step 191: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6604
# Step 192: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6605
# Step 193: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6607
# Step 194: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6610
# Step 195: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6614
# Step 196: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6620
# Step 197: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6625
# Step 198: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6632
# Step 199: Loss: 0.0264, Total Entropy: 0.0031, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0031, Distance: 4.6639
# Step 00: Loss: 1.5222, Total Entropy: 1.5222, Epistemic Entropy: 0.0212, Aleatoric Entropy: 1.5011, Distance: 0.0000
# Step 01: Loss: 0.7203, Total Entropy: 0.7123, Epistemic Entropy: 0.0092, Aleatoric Entropy: 0.7031, Distance: 1.6000
# Step 02: Loss: 0.1607, Total Entropy: 0.1464, Epistemic Entropy: 0.0015, Aleatoric Entropy: 0.1449, Distance: 2.8644
# Step 03: Loss: 0.0462, Total Entropy: 0.0258, Epistemic Entropy: 0.0002, Aleatoric Entropy: 0.0256, Distance: 4.0856
# Step 04: Loss: 0.0312, Total Entropy: 0.0055, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0055, Distance: 5.1362
# Step 05: Loss: 0.0316, Total Entropy: 0.0015, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0015, Distance: 6.0313
# Step 06: Loss: 0.0345, Total Entropy: 0.0005, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0005, Distance: 6.7997
# ...
# Step 66: Loss: 0.0277, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 5.5128
# Step 67: Loss: 0.0271, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 5.4024
# Step 68: Loss: 0.0266, Total Entropy: 0.0001, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0001, Distance: 5.2925
# Step 69: Loss: 0.0261, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 5.1831
# Step 70: Loss: 0.0256, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 5.0744
# Step 71: Loss: 0.0251, Total Entropy: 0.0002, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0002, Distance: 4.9664
# Step 72: Loss: 0.0246, Total Entropy: 0.0003, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0003, Distance: 4.8593
# Step 73: Loss: 0.0241, Total Entropy: 0.0003, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0003, Distance: 4.7531
# Step 74: Loss: 0.0236, Total Entropy: 0.0004, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0004, Distance: 4.6481
# Step 75: Loss: 0.0232, Total Entropy: 0.0005, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0005, Distance: 4.5443
# Step 76: Loss: 0.0228, Total Entropy: 0.0006, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0006, Distance: 4.4421
# Step 77: Loss: 0.0224, Total Entropy: 0.0007, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0007, Distance: 4.3416
# Step 78: Loss: 0.0220, Total Entropy: 0.0008, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0008, Distance: 4.2431
# Step 79: Loss: 0.0217, Total Entropy: 0.0010, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0009, Distance: 4.1471
# Step 80: Loss: 0.0214, Total Entropy: 0.0011, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0011, Distance: 4.0537
# Step 81: Loss: 0.0211, Total Entropy: 0.0013, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0013, Distance: 3.9636
# Step 82: Loss: 0.0209, Total Entropy: 0.0015, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0015, Distance: 3.8772
# Step 83: Loss: 0.0207, Total Entropy: 0.0017, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0017, Distance: 3.7951
# Step 84: Loss: 0.0206, Total Entropy: 0.0020, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0020, Distance: 3.7178
# Step 85: Loss: 0.0205, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0022, Distance: 3.6461
# Step 86: Loss: 0.0204, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.5807
# Step 87: Loss: 0.0204, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 3.5221
# Step 88: Loss: 0.0203, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 3.4711
# Step 89: Loss: 0.0203, Total Entropy: 0.0032, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0032, Distance: 3.4280
# Step 90: Loss: 0.0203, Total Entropy: 0.0034, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0033, Distance: 3.3933
# Step 91: Loss: 0.0203, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 3.3671
# Step 92: Loss: 0.0203, Total Entropy: 0.0036, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0036, Distance: 3.3492
# Step 93: Loss: 0.0203, Total Entropy: 0.0036, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0036, Distance: 3.3394
# Step 94: Loss: 0.0203, Total Entropy: 0.0036, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0036, Distance: 3.3371
# Step 95: Loss: 0.0203, Total Entropy: 0.0035, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0035, Distance: 3.3414
# Step 96: Loss: 0.0202, Total Entropy: 0.0034, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0034, Distance: 3.3513
# Step 97: Loss: 0.0202, Total Entropy: 0.0033, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0033, Distance: 3.3657
# Step 98: Loss: 0.0201, Total Entropy: 0.0032, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0032, Distance: 3.3836
# Step 99: Loss: 0.0201, Total Entropy: 0.0030, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0030, Distance: 3.4037
# Step 100: Loss: 0.0200, Total Entropy: 0.0029, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0029, Distance: 3.4250
# Step 101: Loss: 0.0200, Total Entropy: 0.0028, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0027, Distance: 3.4464
# Step 102: Loss: 0.0200, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4672
# Step 103: Loss: 0.0200, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4867
# Step 104: Loss: 0.0200, Total Entropy: 0.0024, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0024, Distance: 3.5042
# Step 105: Loss: 0.0200, Total Entropy: 0.0024, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0023, Distance: 3.5195
# Step 106: Loss: 0.0199, Total Entropy: 0.0023, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0023, Distance: 3.5322
# Step 107: Loss: 0.0199, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0022, Distance: 3.5422
# Step 108: Loss: 0.0199, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0022, Distance: 3.5494
# Step 109: Loss: 0.0199, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0022, Distance: 3.5538
# Step 110: Loss: 0.0199, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0021, Distance: 3.5557
# Step 111: Loss: 0.0199, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0021, Distance: 3.5552
# Step 112: Loss: 0.0199, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0021, Distance: 3.5525
# Step 113: Loss: 0.0199, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0022, Distance: 3.5480
# Step 114: Loss: 0.0199, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0022, Distance: 3.5418
# Step 115: Loss: 0.0199, Total Entropy: 0.0022, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0022, Distance: 3.5344
# Step 116: Loss: 0.0199, Total Entropy: 0.0023, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0023, Distance: 3.5260
# Step 117: Loss: 0.0199, Total Entropy: 0.0023, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0023, Distance: 3.5170
# Step 118: Loss: 0.0199, Total Entropy: 0.0024, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0023, Distance: 3.5077
# Step 119: Loss: 0.0199, Total Entropy: 0.0024, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0024, Distance: 3.4984
# Step 120: Loss: 0.0199, Total Entropy: 0.0024, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0024, Distance: 3.4893
# Step 121: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4808
# Step 122: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4729
# Step 123: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4660
# Step 124: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4601
# Step 125: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4552
# Step 126: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4515
# Step 127: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4489
# Step 128: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4475
# Step 129: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4470
# Step 130: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4474
# Step 131: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4487
# Step 132: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4506
# Step 133: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4530
# Step 134: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4558
# Step 135: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0026, Distance: 3.4588
# Step 136: Loss: 0.0199, Total Entropy: 0.0026, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4619
# Step 137: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4649
# Step 138: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4679
# Step 139: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4706
# Step 140: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4730
# Step 141: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4751
# Step 142: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4768
# Step 143: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4781
# Step 144: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0024, Distance: 3.4790
# Step 145: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0024, Distance: 3.4795
# Step 146: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0024, Distance: 3.4797
# Step 147: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0024, Distance: 3.4795
# Step 148: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0024, Distance: 3.4791
# Step 149: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0024, Distance: 3.4784
# Step 150: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4776
# Step 151: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4766
# Step 152: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4755
# Step 153: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4744
# Step 154: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4733
# Step 155: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4722
# Step 156: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4712
# Step 157: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4704
# Step 158: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4696
# Step 159: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4690
# Step 160: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4686
# Step 161: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4682
# Step 162: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4681
# Step 163: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4681
# Step 164: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4681
# Step 165: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4683
# Step 166: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4686
# Step 167: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4689
# Step 168: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4693
# Step 169: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4697
# Step 170: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4700
# Step 171: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4704
# Step 172: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4707
# Step 173: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4710
# Step 174: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4713
# Step 175: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4715
# Step 176: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4716
# Step 177: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4717
# Step 178: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4718
# Step 179: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4718
# Step 180: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4718
# Step 181: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4717
# Step 182: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4716
# Step 183: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4715
# Step 184: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4713
# Step 185: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4712
# Step 186: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4711
# Step 187: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4710
# Step 188: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4709
# Step 189: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4708
# Step 190: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4707
# Step 191: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4707
# Step 192: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4706
# Step 193: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4706
# Step 194: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4706
# Step 195: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4706
# Step 196: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4706
# Step 197: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4707
# Step 198: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4707
# Step 199: Loss: 0.0199, Total Entropy: 0.0025, Epistemic Entropy: 0.0000, Aleatoric Entropy: 0.0025, Distance: 3.4707
#
# Results over 50 most uncertain images:
# Average latent entropy reduction: 0.982
# Average reconstruction entropy reduction: 0.062
# Average distance between original and explained latents: 3.925

# %% [markdown]
# Test on the Deterministic last layer

# %%
# Get 50 most uncertain images
uncertain_indices = sorted_data_indices[:50]

# Initialize lists to store metrics
latent_entropy_reductions = []
recon_entropy_reductions = []
distances = []

# Process each uncertain image
for idx in uncertain_indices:
    uncertain_image, _ = testset[idx]
    uncertain_image = uncertain_image.to(cfg.device).unsqueeze(0)  # Add batch dimension

    # Get latent representation
    backbone.eval()
    with torch.no_grad():
        z0, _ = backbone(uncertain_image)

    # Initialize CLUE
    clue = new_CLUE.NewCLUE(
        classifier=backbone.classifier,  # Just use the classifier head
        z0=z0,
        uncertainty_weight=1.0,
        distance_weight=0.005,
        lr=0.1,
        device=cfg.device,
        bayesian=False,  # Non-Bayesian mode
        verbose=False
    )

    # Optimize to find explanation
    z_explained = clue.optimize(steps=400)

    # Calculate distance between original and explained latent codes
    distance = torch.norm(z0 - z_explained).item()
    distances.append(distance)

    # Generate reconstructions using decoder
    with torch.no_grad():
        # Original reconstruction
        original_recon = decoder(z0)
        # CLUE reconstruction  
        clue_recon = decoder(z_explained)
        
        # Get predictions from classifier head
        original_logits = backbone.classifier(z0)
        explained_logits = backbone.classifier(z_explained)
        
        # Convert to probabilities
        original_probs = torch.nn.functional.softmax(original_logits, dim=1)
        explained_probs = torch.nn.functional.softmax(explained_logits, dim=1)
        
        # Get predictions from full classifier workflow on reconstructions
        _, original_recon_logits = backbone(original_recon)
        _, explained_recon_logits = backbone(clue_recon)
        
        original_recon_probs = torch.nn.functional.softmax(original_recon_logits, dim=1)
        explained_recon_probs = torch.nn.functional.softmax(explained_recon_logits, dim=1)
        
        # Calculate entropies for latent predictions
        original_entropy_latent = -(original_probs * torch.log(original_probs + 1e-10)).sum(dim=1)
        explained_entropy_latent = -(explained_probs * torch.log(explained_probs + 1e-10)).sum(dim=1)
        
        # Calculate entropies for reconstruction predictions
        original_entropy_recon = -(original_recon_probs * torch.log(original_recon_probs + 1e-10)).sum(dim=1)
        explained_entropy_recon = -(explained_recon_probs * torch.log(explained_recon_probs + 1e-10)).sum(dim=1)

        # Calculate entropy reductions
        latent_entropy_reduction = (original_entropy_latent - explained_entropy_latent).item()
        recon_entropy_reduction = (original_entropy_recon - explained_entropy_recon).item()
        
        latent_entropy_reductions.append(latent_entropy_reduction)
        recon_entropy_reductions.append(recon_entropy_reduction)

# Calculate averages
avg_latent_entropy_reduction = np.mean(latent_entropy_reductions)
avg_recon_entropy_reduction = np.mean(recon_entropy_reductions)
avg_distance = np.mean(distances)

print(f"\nResults over {len(uncertain_indices)} most uncertain images:")
print(f"Average latent entropy reduction: {avg_latent_entropy_reduction:.3f}")
print(f"Average reconstruction entropy reduction: {avg_recon_entropy_reduction:.3f}")
print(f"Average distance between original and explained latents: {avg_distance:.3f}")
# Out:
# Results over 50 most uncertain images:
# Average latent entropy reduction: 0.775
# Average reconstruction entropy reduction: 0.160
# Average distance between original and explained latents: 5.906

# %% [markdown]
# Test on the VI BLL

# %%
# Get 50 most uncertain images
uncertain_indices = sorted_data_indices[:50]

# Initialize lists to store metrics
latent_entropy_reductions = []
recon_entropy_reductions = []
distances = []

# Process each uncertain image
for idx in uncertain_indices:
    uncertain_image, _ = testset[idx]
    uncertain_image = uncertain_image.to(cfg.device).unsqueeze(0)  # Add batch dimension

    # Get latent representation
    bll_vi.eval()
    with torch.no_grad():
        z0 = bll_vi.extract_features(uncertain_image)

    # Initialize CLUE
    clue = new_CLUE.NewCLUE(
        classifier=bll_vi,
        z0=z0,
        uncertainty_weight=1.0,
        distance_weight=0.005,
        lr=0.1,
        device=cfg.device,
        bayesian=True, 
        verbose=False
    )

    # Optimize to find explanation
    z_explained = clue.optimize(steps=200)

    # Calculate distance between original and explained latent codes
    distance = torch.norm(z0 - z_explained).item()
    distances.append(distance)

    # Generate reconstructions using decoder
    with torch.no_grad():
        # Original reconstruction
        original_recon = decoder(z0)
        # CLUE reconstruction  
        clue_recon = decoder(z_explained)
        
        # Get predictions and uncertainties from latent codes
        original_probs_latent = bll_vi.sample_predict_z(z0)
        explained_probs_latent = bll_vi.sample_predict_z(z_explained)
        
        # Get predictions from full classifier workflow on reconstructions
        original_probs_recon = bll_vi.sample_predict(original_recon)
        explained_probs_recon = bll_vi.sample_predict(clue_recon)
        
        # Calculate mean probabilities and entropies for latent predictions
        original_mean_probs_latent = original_probs_latent.mean(dim=0)
        explained_mean_probs_latent = explained_probs_latent.mean(dim=0)
        
        original_entropy_latent = -(original_mean_probs_latent * torch.log(original_mean_probs_latent + 1e-10)).sum(dim=1)
        explained_entropy_latent = -(explained_mean_probs_latent * torch.log(explained_mean_probs_latent + 1e-10)).sum(dim=1)
        
        # Calculate mean probabilities and entropies for reconstruction predictions
        original_mean_probs_recon = original_probs_recon.mean(dim=0)
        explained_mean_probs_recon = explained_probs_recon.mean(dim=0)
        
        original_entropy_recon = -(original_mean_probs_recon * torch.log(original_mean_probs_recon + 1e-10)).sum(dim=1)
        explained_entropy_recon = -(explained_mean_probs_recon * torch.log(explained_mean_probs_recon + 1e-10)).sum(dim=1)

        # Calculate entropy reductions
        latent_entropy_reduction = (original_entropy_latent - explained_entropy_latent).item()
        recon_entropy_reduction = (original_entropy_recon - explained_entropy_recon).item()
        
        latent_entropy_reductions.append(latent_entropy_reduction)
        recon_entropy_reductions.append(recon_entropy_reduction)

# Calculate averages
avg_latent_entropy_reduction = np.mean(latent_entropy_reductions)
avg_recon_entropy_reduction = np.mean(recon_entropy_reductions)
avg_distance = np.mean(distances)

print(f"\nResults over {len(uncertain_indices)} most uncertain images:")
print(f"Average latent entropy reduction: {avg_latent_entropy_reduction:.3f}")
print(f"Average reconstruction entropy reduction: {avg_recon_entropy_reduction:.3f}")
print(f"Average distance between original and explained latents: {avg_distance:.3f}")
# Out:
# Results over 50 most uncertain images:
# Average latent entropy reduction: 1.044
# Average reconstruction entropy reduction: 0.311
# Average distance between original and explained latents: 9.147

# %% [markdown]
# ### Visualise the results between all models

# %%
# Get indices of 2 most uncertain images
n_examples = 10
uncertain_indices = sorted_data_indices[9:9+n_examples]

# Set up the plot - now 5 rows
fig, axes = plt.subplots(5, n_examples, figsize=(20, 15))  # Doubled the width from 10 to 20
plt.subplots_adjust(wspace=0.3, hspace=0.8)  # Increased vertical spacing

# Add horizontal y-axis labels with larger font - adjusted y-coordinates
fig.text(0.02, 0.55, 'MCMC CLUE', ha='left', va='center', fontsize=12, fontweight='bold')
fig.text(0.02, 0.35, 'Det CLUE', ha='left', va='center', fontsize=12, fontweight='bold')
fig.text(0.02, 0.15, 'VI CLUE', ha='left', va='center', fontsize=12, fontweight='bold')

for i, idx in enumerate(uncertain_indices):
    # Get image
    uncertain_image, _ = testset[idx]
    uncertain_image = uncertain_image.to(cfg.device).unsqueeze(0)
    
    # Get original latent representations and entropies
    with torch.no_grad():
        # Get original features and entropies
        z0_mcmc = bll.extract_features(uncertain_image)
        mcmc_orig_probs = bll.sample_predict_z(z0_mcmc).mean(0)
        mcmc_orig_entropy = -(mcmc_orig_probs * torch.log(mcmc_orig_probs + 1e-10)).sum(1)
        
        z0_det, _ = backbone(uncertain_image)
        det_orig_logits = backbone.classifier(z0_det)
        det_orig_probs = torch.nn.functional.softmax(det_orig_logits, dim=1)
        det_orig_entropy = -(det_orig_probs * torch.log(det_orig_probs + 1e-10)).sum(1)
        
        z0_vi = bll_vi.extract_features(uncertain_image)
        vi_orig_probs = bll_vi.sample_predict_z(z0_vi).mean(0)
        vi_orig_entropy = -(vi_orig_probs * torch.log(vi_orig_probs + 1e-10)).sum(1)
    
    # Original image with all entropies
    axes[0,i].imshow(uncertain_image.squeeze().cpu(), cmap='gray')
    axes[0,i].axis('off')
    axes[0,i].set_title(f'Original\nMCMC: {mcmc_orig_entropy[0]:.3f}\nDet: {det_orig_entropy[0]:.3f}\nVI: {vi_orig_entropy[0]:.3f}')
    
    # Original reconstruction and its entropies
    with torch.no_grad():
        # Get reconstruction
        recon = decoder(z0_mcmc)  # Can use any of the z0s since they should give similar reconstructions
        
        # Get reconstruction entropies for each model
        mcmc_recon_probs = bll.sample_predict(recon).mean(0)
        mcmc_recon_entropy = -(mcmc_recon_probs * torch.log(mcmc_recon_probs + 1e-10)).sum(1)
        
        _, det_recon_logits = backbone(recon)
        det_recon_probs = torch.nn.functional.softmax(det_recon_logits, dim=1)
        det_recon_entropy = -(det_recon_probs * torch.log(det_recon_probs + 1e-10)).sum(1)
        
        vi_recon_probs = bll_vi.sample_predict(recon).mean(0)
        vi_recon_entropy = -(vi_recon_probs * torch.log(vi_recon_probs + 1e-10)).sum(1)
    
    # Plot original reconstruction
    axes[1,i].imshow(recon[0,0].cpu().detach(), cmap='gray')
    axes[1,i].axis('off')
    axes[1,i].set_title(f'Original Recon\nMCMC: {mcmc_recon_entropy[0]:.3f}\nDet: {det_recon_entropy[0]:.3f}\nVI: {vi_recon_entropy[0]:.3f}')
    
    # Generate counterfactuals
    clue_mcmc = new_CLUE.NewCLUE(
        classifier=bll,
        z0=z0_mcmc,
        uncertainty_weight=1.0,
        distance_weight=0.005,
        lr=0.1,
        device=cfg.device,
        bayesian=True,
        verbose=False
    )
    z_explained_mcmc = clue_mcmc.optimize(steps=200)
    
    clue_det = new_CLUE.NewCLUE(
        classifier=backbone.classifier,
        z0=z0_det,
        uncertainty_weight=1.0,
        distance_weight=0.005,
        lr=0.1,
        device=cfg.device,
        bayesian=False,
        verbose=False
    )
    z_explained_det = clue_det.optimize(steps=200)
    
    clue_vi = new_CLUE.NewCLUE(
        classifier=bll_vi,
        z0=z0_vi,
        uncertainty_weight=1.0,
        distance_weight=0.005,
        lr=0.1,
        device=cfg.device,
        bayesian=True,
        verbose=False
    )
    z_explained_vi = clue_vi.optimize(steps=200)
    
    # Generate counterfactual reconstructions and compute entropies
    with torch.no_grad():
        # MCMC counterfactual
        mcmc_recon = decoder(z_explained_mcmc)
        mcmc_probs = bll.sample_predict_z(z_explained_mcmc).mean(0)
        mcmc_entropy = -(mcmc_probs * torch.log(mcmc_probs + 1e-10)).sum(1)
        mcmc_recon_probs = bll.sample_predict(mcmc_recon).mean(0)
        mcmc_recon_entropy = -(mcmc_recon_probs * torch.log(mcmc_recon_probs + 1e-10)).sum(1)
        
        # Det counterfactual
        det_recon = decoder(z_explained_det)
        det_logits = backbone.classifier(z_explained_det)
        det_probs = torch.nn.functional.softmax(det_logits, dim=1)
        det_entropy = -(det_probs * torch.log(det_probs + 1e-10)).sum(1)
        _, det_recon_logits = backbone(det_recon)
        det_recon_probs = torch.nn.functional.softmax(det_recon_logits, dim=1)
        det_recon_entropy = -(det_recon_probs * torch.log(det_recon_probs + 1e-10)).sum(1)
        
        # VI counterfactual
        vi_recon = decoder(z_explained_vi)
        vi_probs = bll_vi.sample_predict_z(z_explained_vi).mean(0)
        vi_entropy = -(vi_probs * torch.log(vi_probs + 1e-10)).sum(1)
        vi_recon_probs = bll_vi.sample_predict(vi_recon).mean(0)
        vi_recon_entropy = -(vi_recon_probs * torch.log(vi_recon_probs + 1e-10)).sum(1)
    
    # Plot counterfactuals (without model names in titles)
    axes[2,i].imshow(mcmc_recon[0,0].cpu().detach(), cmap='gray')
    axes[2,i].axis('off')
    axes[2,i].set_title(f'Latent: {mcmc_entropy[0]:.3f}\nRecon: {mcmc_recon_entropy[0]:.3f}')
    
    axes[3,i].imshow(det_recon[0,0].cpu().detach(), cmap='gray')
    axes[3,i].axis('off')
    axes[3,i].set_title(f'Latent: {det_entropy[0]:.3f}\nRecon: {det_recon_entropy[0]:.3f}')
    
    axes[4,i].imshow(vi_recon[0,0].cpu().detach(), cmap='gray')
    axes[4,i].axis('off')
    axes[4,i].set_title(f'Latent: {vi_entropy[0]:.3f}\nRecon: {vi_recon_entropy[0]:.3f}')

plt.show()
